# %% [markdown]
# # Paper panels
#
# Run `python run_all_paper_experiments.py` first. This notebook displays the saved map and population data; displacement and sparse connectivity are derived live from the trained 90x90 maps.

# %%
from helpers.paper_panel_plotting import (
    load_paper_bundle,
    plot_core_sweep_summary,
    plot_map_organisation,
    plot_displacement_and_connectivity,
    plot_population_embeddings,
)
bundle = load_paper_bundle()

# %% [markdown]
# ## Fidelity, complexity, and robustness sweeps

# %%
plot_core_sweep_summary();

# %% [markdown]
# ## Developed macro- and micro-domain maps

# %%
plot_map_organisation(bundle);

# %% [markdown]
# ## Positional displacement and Van-Hooser-style connectivity readout

# %%
plot_displacement_and_connectivity(
    bundle,
    subtractive_threshold=1.5,  # multiples of the global mean weight
    connection_fraction=0.25,   # fraction retained after thresholding
    sigma=1.5,                 # any non-negative value, in lattice units
    show=True,
);

# %% [markdown]
# ## Grating and population-response embeddings

# %%
# %matplotlib widget
plot_population_embeddings(bundle);
